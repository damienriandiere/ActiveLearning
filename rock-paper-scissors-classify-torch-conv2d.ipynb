# %% [markdown]
# # Rock-Paper-Scissors Classify Torch Conv2d

# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm.notebook import tqdm
from torchvision import datasets, transforms, models 
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor
from torchvision.utils import make_grid
from torch.utils.data import random_split
from torch.utils.data.dataloader import DataLoader
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_dir = '../input/rock-paper-scissors-dataset/train'
test_dir = '../input/rock-paper-scissors-dataset/test'
valid_dir = '../input/rock-paper-scissors-dataset/val'
classes = os.listdir(data_dir)
print(classes)
print(len(classes))
# Out:
# ['paper', 'rock', 'scissors']
# 3

# %%
train_transform=transforms.Compose([
        transforms.RandomRotation(10),      # rotate +/- 10 degrees
        transforms.RandomHorizontalFlip(),  # reverse 50% of images
        transforms.Resize(100),             # resize shortest side to 100 pixels
        transforms.CenterCrop(100),         # crop longest side to 100 pixels at center
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
])

# %%
dataset = ImageFolder(data_dir, transform=train_transform)
testset = ImageFolder(test_dir, transform=train_transform)
validset = ImageFolder(valid_dir, transform=train_transform)

# %%
# view one image shape of the dataset.
img, label = dataset[100]
print(img.shape)
# Out:
# torch.Size([3, 100, 100])

# %%
# function for the showing the image.
def show_image(img, label):
    print('Label: ', dataset.classes[label], "("+str(label)+")")
    plt.imshow(img.permute(1, 2, 0))

# %%
show_image(*dataset[20])
# Out:
# Label:  paper (0)

# %%
show_image(*dataset[300])
# Out:
# Label:  paper (0)

# %%
torch.manual_seed(20)
train_size = len(dataset)
val_size = len(validset)
test_size = len(testset)

# %%
train_ds = dataset
val_ds = validset
test_ds = testset
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (1020, 804, 540)

# %%
batch_size = 64
train_loader = DataLoader(train_ds, batch_size, shuffle=True, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_ds, batch_size*2, num_workers=4, pin_memory=True)
test_loader = DataLoader(test_ds, batch_size*2, num_workers=4, pin_memory=True)

# %%
for images, labels in train_loader:
    fig, ax = plt.subplots(figsize=(18,10))
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(make_grid(images, nrow=16).permute(1, 2, 0))
    break

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['train_loss'], result['val_loss'], result['val_acc']))

# %%
def evaluate(model, val_loader):
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)


def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        for batch in tqdm(train_loader):
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
torch.cuda.is_available()
# Out:
# False

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cpu')

# %%
train_loader = DeviceDataLoader(train_loader, device)
val_loader = DeviceDataLoader(val_loader, device)
test_loader = DeviceDataLoader(test_loader, device)

# %%
input_size = 3*100*100
output_size = len(classes)

# %% [markdown]
# # Conv2d Model

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                   # Generate predictions
        loss = F.cross_entropy(out, labels)  # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['train_loss'], result['val_loss'], result['val_acc']))

# %%
class CnnModel(ImageClassificationBase):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 100, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(100, 150, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 150 x 16 x 16

            nn.Conv2d(150, 200, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(200, 200, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 200 x 8 x 8

            nn.Conv2d(200, 250, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(250, 250, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # output: 250 x 4 x 4

            nn.Flatten(), 
            nn.Linear(36000, 1000),
            nn.ReLU(),
            nn.Linear(1000, 500),
            nn.ReLU(),
            nn.Dropout(0.25),
            nn.Linear(500, output_size))
        
    def forward(self, xb):
        return self.network(xb)

# %%
model = CnnModel()
#model.cuda()

# %%
model
# Out:
# CnnModel(
#   (network): Sequential(
#     (0): Conv2d(3, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(100, 150, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(150, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(200, 250, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Conv2d(250, 250, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Flatten(start_dim=1, end_dim=-1)
#     (16): Linear(in_features=36000, out_features=1000, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=1000, out_features=500, bias=True)
#     (19): ReLU()
#     (20): Dropout(p=0.25, inplace=False)
#     (21): Linear(in_features=500, out_features=3, bias=True)
#   )
# )

# %%
for images, labels in train_loader:
    print('images.shape:', images.shape)
    out = model(images)
    print('out.shape:', out.shape)
    #print('out[0]:', out[0])
    break
# Out:
# images.shape: torch.Size([64, 3, 100, 100])
# out.shape: torch.Size([64, 3])

# %%
device = get_default_device()
device
# Out:
# device(type='cpu')

# %%
train_dl = DeviceDataLoader(train_loader, device)
val_dl = DeviceDataLoader(val_loader, device)
to_device(model, device)
# Out:
# CnnModel(
#   (network): Sequential(
#     (0): Conv2d(3, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(100, 150, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(150, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(200, 200, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(200, 250, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Conv2d(250, 250, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Flatten(start_dim=1, end_dim=-1)
#     (16): Linear(in_features=36000, out_features=1000, bias=True)
#     (17): ReLU()
#     (18): Linear(in_features=1000, out_features=500, bias=True)
#     (19): ReLU()
#     (20): Dropout(p=0.25, inplace=False)
#     (21): Linear(in_features=500, out_features=3, bias=True)
#   )
# )

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        for batch in tqdm(train_loader):
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
model = to_device(CnnModel(), device)

# %%
history=[evaluate(model, val_loader)]
history
# Out:
# [{'val_loss': 1.1006791591644287, 'val_acc': 0.3002232015132904}]

# %%
num_epochs = 20
opt_func = torch.optim.Adam
lr = 0.001

# %%
history+= fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [0], train_loss: 1.1059, val_loss: 1.1004, val_acc: 0.3002
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [1], train_loss: 1.0981, val_loss: 1.1026, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [2], train_loss: 1.0983, val_loss: 1.1036, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [3], train_loss: 1.1004, val_loss: 1.1019, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [4], train_loss: 1.0979, val_loss: 1.1006, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [5], train_loss: 1.0982, val_loss: 1.1010, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [6], train_loss: 1.0978, val_loss: 1.1018, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [7], train_loss: 1.0977, val_loss: 1.1021, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [8], train_loss: 1.0979, val_loss: 1.1033, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [9], train_loss: 1.0978, val_loss: 1.1032, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [10], train_loss: 1.0981, val_loss: 1.1034, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [11], train_loss: 1.0976, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [12], train_loss: 1.0977, val_loss: 1.1026, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [13], train_loss: 1.0982, val_loss: 1.1032, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [14], train_loss: 1.0981, val_loss: 1.1048, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [15], train_loss: 1.0977, val_loss: 1.1034, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [16], train_loss: 1.0975, val_loss: 1.1034, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [17], train_loss: 1.0982, val_loss: 1.1026, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [18], train_loss: 1.0977, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [19], train_loss: 1.0974, val_loss: 1.1029, val_acc: 0.2980

# %%
history+= fit(num_epochs, lr/10, model, train_dl, val_dl, opt_func)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [0], train_loss: 1.0976, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [1], train_loss: 1.0976, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [2], train_loss: 1.0975, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [3], train_loss: 1.0977, val_loss: 1.1027, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [4], train_loss: 1.0976, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [5], train_loss: 1.0973, val_loss: 1.1030, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [6], train_loss: 1.0977, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [7], train_loss: 1.0975, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [8], train_loss: 1.0975, val_loss: 1.1030, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [9], train_loss: 1.0974, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [10], train_loss: 1.0976, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [11], train_loss: 1.0974, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [12], train_loss: 1.0975, val_loss: 1.1031, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [13], train_loss: 1.0978, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [14], train_loss: 1.0978, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [15], train_loss: 1.0975, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [16], train_loss: 1.0977, val_loss: 1.1031, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [17], train_loss: 1.0975, val_loss: 1.1029, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [18], train_loss: 1.0980, val_loss: 1.1030, val_acc: 0.2980
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch [19], train_loss: 1.0976, val_loss: 1.1030, val_acc: 0.2980

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs')
    plt.show()
    
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs')
    plt.show()

# %%
plot_accuracies(history)

# %%
plot_losses(history)

# %%
evaluate(model, test_loader)
# Out:
# {'val_loss': 1.1051992177963257, 'val_acc': 0.2750000059604645}

# %%
from sklearn.metrics import classification_report

pred = []
Y = []
for i, (x,y) in enumerate(test_loader):
    with torch.no_grad():
        output = model(x)
    pred += [int(l.argmax()) for l in output]
    Y += [int(l) for l in y]

print(classification_report(Y, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.49       176
#            1       0.00      0.00      0.00       188
#            2       0.00      0.00      0.00       176
#
#     accuracy                           0.33       540
#    macro avg       0.11      0.33      0.16       540
# weighted avg       0.11      0.33      0.16       540
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
